# %% [markdown]
# # AlphaStream Intelligence — Next Steps
# > Conducted 2026-03-29
#
# -----
# ## PHASE 1) Optimization of current level
# * We are missing the speed when loading opening a new component.
# For example:
# 1. We need to improve the pace of which the current components are loading. It needs to be faster.
# 2. We need to optimize the backend, to ensure that everything moves faster and ensure that we have updateed information.
#
# ## Phase 2 - Improving the existing
# 1. We need to update the sector and industry for all stocks [screener.tsx]
# 2. Same design for the active index sheet and active stock sheet.[activate_stock_sheet.tsx] [active_index_sheet] but only for the components that are the same.
# 3. Marked cap, P/E, ROE, Gross Margin, Net Margin. Change metrics if needed. Store in supabase for easy access and pulling[watchlist.tsx]
# 4. Include more price points on the activate_stock_sheet.tsx for the chart for 30D prices. When we call the API on the price data for instance on apple we get price points for the past 3 months:
#
# https://financialmodelingprep.com/stable/historical-chart/1hour?symbol=AAPL&apikey=MkLiDbWK4GITp2YLGtkhfe0qG3MzIsMC
#
# [
#   {
#     "date": "2026-03-27 15:30:00",
#     "open": 248.41,
#     "low": 248.08,
#     "high": 249.37,
#     "close": 248.63,
#     "volume": 2120182
#   },
#   {
#     "date": "2026-03-27 14:30:00",
#     "open": 249.4,
#     "low": 248.27,
#     "high": 249.52,
#     "close": 248.39,
#     "volume": 4113587
#   },
# ......
#  {
#     "date": "2025-12-30 10:30:00",
#     "open": 272.58,
#     "low": 272.42,
#     "high": 273.31,
#     "close": 272.85,
#     "volume": 1711221
#   },
#   {
#     "date": "2025-12-30 09:30:00",
#     "open": 272.82,
#     "low": 272.4,
#     "high": 274.06,
#     "close": 272.6,
#     "volume": 3335833
#   }
# ]
#
#
# ## Phase 3 - New front-end for Chat-Field
# 1. We need to improve the front-end for chat input field. Take notes from Perplexity Finance and copy their design. We need to simulate a conversation. When i write "Hello World" I want to be generated a response and review the output. I want this to apply to all text input bars. I do not care how you solve it, if it becomes a pop-up menu that is completely fine
